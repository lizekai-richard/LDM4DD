# %% [markdown]
# Temporary cleaning script to remove images with index names

# %%
import os
ipc_500_root = '/mnt/data/zekai/CIFAR10_Syn/ipc500'
classes = os.listdir(ipc_500_root)

# %%
for cls in classes:
    cls_dir = os.path.join(ipc_500_root, cls)
    for image in os.listdir(cls_dir):
        # Remove indexed images, eg. 100.png
        if len(image) < 10: 
            os.remove(os.path.join(cls_dir, image))

# %% [markdown]
# Check for number of images per class

# %%
[len(os.listdir(os.path.join(ipc_500_root, x))) for x in classes]
# Out:
# [3000, 3000, 3000, 3000, 3000, 3000, 3000, 3000, 3000, 3000]

# %% [markdown]
# 512 images per class for ipc 500

# %% [markdown]
# Generate index file for these images

# %%
class_to_idx = {'airplane': 0,
                'automobile': 1,
                'bird': 2,
                'cat': 3,
                'deer': 4,
                'dog': 5,
                'frog': 6,
                'horse': 7,
                'ship': 8,
                'truck': 9}

# %%
import pandas as pd

entries = []
for cls in classes:
    cls_idx = class_to_idx[cls]
    cls_dir = os.path.join(ipc_500_root, cls)
    for image in os.listdir(cls_dir):
        # On windows, manually writing path in linux format
        entries.append([f'/mnt/data/zekai/CIFAR10_Syn/ipc500/{cls}/{image}', cls_idx])
entries
# Out:
# [['/mnt/data/zekai/CIFAR10_Syn/ipc500/ship/33ea4ff1-b670-4861-96a5-b0eb18a421a3.png',
#   8],
#  ['/mnt/data/zekai/CIFAR10_Syn/ipc500/ship/8541b79e-d4db-4d46-917e-2f33500466ec.png',
#   8],
#  ['/mnt/data/zekai/CIFAR10_Syn/ipc500/ship/32c88051-8f0a-41bc-9a96-751e3ae9469b.png',
#   8],
#  ['/mnt/data/zekai/CIFAR10_Syn/ipc500/ship/ebba09f9-f730-4bef-a7bc-1b699cb771d5.png',
#   8],
#  ['/mnt/data/zekai/CIFAR10_Syn/ipc500/ship/7f91117b-70fb-4d2d-b9c1-c0c3c4d62395.png',
#   8],
#  ['/mnt/data/zekai/CIFAR10_Syn/ipc500/ship/ec23a277-d0a9-4e9e-bff2-c3c6177a8012.png',
#   8],
#  ['/mnt/data/zekai/CIFAR10_Syn/ipc500/ship/1f041221-5bdd-4a88-afeb-15600745b0b4.png',
#   8],
#  ['/mnt/data/zekai/CIFAR10_Syn/ipc500/ship/95965eb0-86d8-469e-b55f-df6f15c08fc3.png',
#   8],
#  ['/mnt/data/zekai/CIFAR10_Syn/ipc500/ship/a6b2bb9e-f590-451c-b19a-ecba8cba98a5.png',
#   8],
#  ['/mnt/data/zekai/CIFAR10_Syn/ipc500/ship/4e82d0e8-8e93-42ab-bedb-bec9c27180b8.png',
#   8],
# ...

# %%
df = pd.DataFrame(entries, columns=['image_path', 'label'])
df
# Out:
#                                               image_path  label
# 0      /mnt/data/zekai/CIFAR10_Syn/ipc500/ship/33ea4f...      8
# 1      /mnt/data/zekai/CIFAR10_Syn/ipc500/ship/8541b7...      8
# 2      /mnt/data/zekai/CIFAR10_Syn/ipc500/ship/32c880...      8
# 3      /mnt/data/zekai/CIFAR10_Syn/ipc500/ship/ebba09...      8
# 4      /mnt/data/zekai/CIFAR10_Syn/ipc500/ship/7f9111...      8
# ...                                                  ...    ...
# 29995  /mnt/data/zekai/CIFAR10_Syn/ipc500/deer/eee776...      4
# 29996  /mnt/data/zekai/CIFAR10_Syn/ipc500/deer/1c9356...      4
# 29997  /mnt/data/zekai/CIFAR10_Syn/ipc500/deer/4c78ba...      4
# 29998  /mnt/data/zekai/CIFAR10_Syn/ipc500/deer/b42c7d...      4
# 29999  /mnt/data/zekai/CIFAR10_Syn/ipc500/deer/c6c847...      4
#
# [30000 rows x 2 columns]

# %%
import os
if not os.path.exists('../CIFAR10_DM_index_files'):
    os.mkdir('../CIFAR10_DM_index_files')

# %%
df.to_csv('../CIFAR10_DM_index_files/ipc500_idx.csv', index=False)

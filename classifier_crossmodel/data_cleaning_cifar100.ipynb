# %% [markdown]
# Temporary cleaning script to remove images with index names

# %%
import os
ipc = 100
ipc_root = f'./CIFAR100_DM/ipc{ipc}'
classes =  os.listdir(ipc_root)

# %%
for cls in classes:
    cls_dir = os.path.join(ipc_root, cls)
    for image in os.listdir(cls_dir):
        # Remove indexed images, eg. 100.png
        if len(image) < 10: 
            os.remove(os.path.join(cls_dir, image))

# %% [markdown]
# Check for number of images per class

# %%
[len(os.listdir(os.path.join(ipc_root, x))) for x in classes]
# Out:
# [100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100]

# %% [markdown]
# Generate index file for these images

# %%
class_to_index = {
    'apple': 0,
    'aquarium_fish': 1,
    'baby': 2,
    'bear': 3,
    'beaver': 4,
    'bed': 5,
    'bee': 6,
    'beetle': 7,
    'bicycle': 8,
    'bottle': 9,
    'bowl': 10,
    'boy': 11,
    'bridge': 12,
    'bus': 13,
    'butterfly': 14,
    'camel': 15,
    'can': 16,
    'castle': 17,
    'caterpillar': 18,
    'cattle': 19,
    'chair': 20,
    'chimpanzee': 21,
    'clock': 22,
    'cloud': 23,
    'cockroach': 24,
    'couch': 25,
    'crab': 26,
    'crocodile': 27,
    'cup': 28,
    'dinosaur': 29,
    'dolphin': 30,
    'elephant': 31,
    'flatfish': 32,
    'forest': 33,
    'fox': 34,
    'girl': 35,
    'hamster': 36,
    'house': 37,
    'kangaroo': 38,
    'keyboard': 39,
    'lamp': 40,
    'lawn_mower': 41,
    'leopard': 42,
    'lion': 43,
    'lizard': 44,
    'lobster': 45,
    'man': 46,
    'maple_tree': 47,
    'motorcycle': 48,
    'mountain': 49,
    'mouse': 50,
    'mushroom': 51,
    'oak_tree': 52,
    'orange': 53,
    'orchid': 54,
    'otter': 55,
    'palm_tree': 56,
    'pear': 57,
    'pickup_truck': 58,
    'pine_tree': 59,
    'plain': 60,
    'plate': 61,
    'poppy': 62,
    'porcupine': 63,
    'possum': 64,
    'rabbit': 65,
    'raccoon': 66,
    'ray': 67,
    'road': 68,
    'rocket': 69,
    'rose': 70,
    'sea': 71,
    'seal': 72,
    'shark': 73,
    'shrew': 74,
    'skunk': 75,
    'skyscraper': 76,
    'snail': 77,
    'snake': 78,
    'spider': 79,
    'squirrel': 80,
    'streetcar': 81,
    'sunflower': 82,
    'sweet_pepper': 83,
    'table': 84,
    'tank': 85,
    'telephone': 86,
    'television': 87,
    'tiger': 88,
    'tractor': 89,
    'train': 90,
    'trout': 91,
    'tulip': 92,
    'turtle': 93,
    'wardrobe': 94,
    'whale': 95,
    'willow_tree': 96,
    'wolf': 97,
    'woman': 98,
    'worm': 99
}

# %%
import pandas as pd

entries = []
for cls in classes:
    cls_idx = int(cls[5:])
    cls_dir = os.path.join(ipc_root, cls)
    for image in os.listdir(cls_dir):
        # On windows, manually writing path in linux format
        entries.append([f'./CIFAR100_DM/ipc{ipc}/{cls}/{image}', cls_idx])
entries
# Out:
# [['./CIFAR100_DM/ipc100/class0/00169883-da36-44ac-8b17-35ec41ae344b.png', 0],
#  ['./CIFAR100_DM/ipc100/class0/03979495-b927-4b32-9a86-c2b875248c38.png', 0],
#  ['./CIFAR100_DM/ipc100/class0/06bbf568-f1cf-4b0e-88f5-4f08dc0ecf8b.png', 0],
#  ['./CIFAR100_DM/ipc100/class0/09183e31-0bf4-4106-aeb7-562748262b3e.png', 0],
#  ['./CIFAR100_DM/ipc100/class0/0a1dddd0-2ee6-4023-994f-1822e9534271.png', 0],
#  ['./CIFAR100_DM/ipc100/class0/0a5504e2-b17c-42fd-ab54-db82d79e9ea0.png', 0],
#  ['./CIFAR100_DM/ipc100/class0/0a8ef117-aa11-4125-ae92-5dd0fa48359a.png', 0],
#  ['./CIFAR100_DM/ipc100/class0/0c286b15-bf34-48e4-b279-18d6b6dc9bf5.png', 0],
#  ['./CIFAR100_DM/ipc100/class0/0d27fc56-2fcf-46e2-9d4f-30bc8617bc1a.png', 0],
#  ['./CIFAR100_DM/ipc100/class0/0dea8dfa-bd5d-4b0b-aa62-52f61a1ae1a2.png', 0],
#  ['./CIFAR100_DM/ipc100/class0/0e005845-6b19-485c-ac14-a38fb3e90db7.png', 0],
#  ['./CIFAR100_DM/ipc100/class0/0fdc8869-535a-4ef5-b13b-910c4b3a4422.png', 0],
# ...

# %%
df = pd.DataFrame(entries, columns=['image_path', 'label'])
df
# Out:
#                                              image_path  label
# 0     ./CIFAR100_DM/ipc100/class0/00169883-da36-44ac...      0
# 1     ./CIFAR100_DM/ipc100/class0/03979495-b927-4b32...      0
# 2     ./CIFAR100_DM/ipc100/class0/06bbf568-f1cf-4b0e...      0
# 3     ./CIFAR100_DM/ipc100/class0/09183e31-0bf4-4106...      0
# 4     ./CIFAR100_DM/ipc100/class0/0a1dddd0-2ee6-4023...      0
# ...                                                 ...    ...
# 9995  ./CIFAR100_DM/ipc100/class99/f9820d24-1cb4-486...     99
# 9996  ./CIFAR100_DM/ipc100/class99/fbf46794-ec4a-413...     99
# 9997  ./CIFAR100_DM/ipc100/class99/fd2ebea7-390b-448...     99
# 9998  ./CIFAR100_DM/ipc100/class99/fd655351-a9e2-45c...     99
# 9999  ./CIFAR100_DM/ipc100/class99/ffebcc02-8ce7-4c6...     99
#
# [10000 rows x 2 columns]

# %%
import os
if not os.path.exists('./CIFAR100_DM_index_files'):
    os.mkdir('./CIFAR100_DM_index_files')

# %%
df.to_csv(f'./CIFAR100_DM_index_files/ipc{ipc}_idx.csv', index=False)
